# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# Collecting git+https://github.com/facebookresearch/segment-anything.git
#   Cloning https://github.com/facebookresearch/segment-anything.git to c:\users\curso\appdata\local\temp\pip-req-build-goq158ti
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit 6fdee8f2727f4506cfbbe553e23b895e27956588
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git 'C:\Users\curso\AppData\Local\Temp\pip-req-build-goq158ti'
#
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install opencv-python pycocotools matplotlib onnxruntime onnx
# Out:
# Requirement already satisfied: opencv-python in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (4.8.0.74)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pycocotools in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (2.0.7)
# Requirement already satisfied: matplotlib in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (3.7.2)
# Requirement already satisfied: onnxruntime in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (1.16.3)
# Requirement already satisfied: onnx in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (1.15.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: coloredlogs in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime) (23.5.26)
# Requirement already satisfied: protobuf in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime) (4.25.1)
# Requirement already satisfied: sympy in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime) (1.12)
# Requirement already satisfied: six>=1.5 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime) (3.4.1)
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (2.0.1)
# Requirement already satisfied: filelock in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch) (1.3.0)
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (0.15.2)
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (1.25.0)
# Requirement already satisfied: requests in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (2.31.0)
# Requirement already satisfied: torch==2.0.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (2.0.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torchvision) (10.0.0)
# Requirement already satisfied: filelock in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision) (4.7.1)
# Requirement already satisfied: sympy in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision) (1.12)
# Requirement already satisfied: networkx in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from requests->torchvision) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch==2.0.1->torchvision) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (4.8.0.74)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from opencv-python) (1.25.0)
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\curso\appdata\local\programs\python\python311\lib\site-packages (from h5py) (1.25.0)
# [notice] A new release of pip is available: 23.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2
import torchvision
import os
import h5py

# %%
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)

    img = np.ones((sorted_anns[0]['segmentation'].shape[0], sorted_anns[0]['segmentation'].shape[1], 4))
    img[:,:,3] = 0
    for ann in sorted_anns:
        m = ann['segmentation']
        color_mask = np.concatenate([np.random.random(3), [0.35]])
        img[m] = color_mask
    ax.imshow(img)

# %%
#Modelo
import sys
sys.path.append("..")
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam_checkpoint = "sam_vit_h_4b8939.pth"
model_type = "vit_h"

device = "cpu"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
sam.to(device=device)

mask_generator = SamAutomaticMaskGenerator(sam)

# %%
mask_generator_2 = SamAutomaticMaskGenerator(
    model=sam,
    points_per_side=32,
    pred_iou_thresh=0.86,
    stability_score_thresh=0.92,
    crop_n_layers=1,
    crop_n_points_downscale_factor=2,
    min_mask_region_area=100,  # Requires open-cv to run post-processing
)

# %%
 # Function to convert list of boolean arrays to uint8 arrays
def bool_array_to_uint8(array):
    return array.astype(np.uint8)

# %%
# Ruta de la carpeta donde se encuentran los archivos
carpeta = "bandej"  # Reemplaza esto con la ruta de tu carpeta

# Crear la carpeta "segmentación" si no existe
general_folder_name = "bandeja"
if not os.path.exists(general_folder_name):
    os.makedirs(general_folder_name)

# Obtener la lista de archivos en la carpeta
archivos = os.listdir(carpeta)

# %%
# Ejemplo de cómo cambiar los nombres de los archivos
for i, nombre_archivo in enumerate(archivos):
    # Verifica si el elemento es un archivo (no un directorio)
    if os.path.isfile(os.path.join(carpeta, nombre_archivo)):
        # Cambiar el nombre del archivo (por ejemplo, agregar '_nuevo' al final del nombre)
        nuevo_nombre = f"{i + 1}.jpg"
        # Ruta completa del archivo original
        ruta_original = os.path.join(carpeta, nombre_archivo)
        # Ruta completa del archivo con el nuevo nombre
        ruta_nueva = os.path.join(general_folder_name, nuevo_nombre)
        # Renombrar el archivo
        os.rename(ruta_original, ruta_nueva)

print("Nombres de archivos cambiados correctamente.")
# Out:
# Nombres de archivos cambiados correctamente.

# %%
# Crear la carpeta "segmentación" si no existe
general_folder_name = "Segmentos"
if not os.path.exists(general_folder_name):
    os.makedirs(general_folder_name)
    
# Crear la carpeta "Matrices" si no existe
name = "Matrices"
if not os.path.exists(name):
    os.makedirs(name)
             
# Obtener la lista de nombres de archivos en la carpeta "Prueba"
folder_path = 'bandeja'
file_names = os.listdir(folder_path)

# Leer cada imagen, convertirla a formato RGB y agregarla a la lista "images"
for file_name in file_names:
    file_path = os.path.join(folder_path, file_name)
    image = cv2.imread(file_path)
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Crear la carpeta para la imagen actual si no existe
    nombre_carpeta_imagen = os.path.join(general_folder_name, file_name[:-4])
    if not os.path.exists(nombre_carpeta_imagen):
            os.makedirs(nombre_carpeta_imagen)
            
    # Guardar la imagen original en la carpeta
    ruta_absoluta = os.path.abspath(os.path.join(nombre_carpeta_imagen, file_name))
    cv2.imwrite(ruta_absoluta, cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR))
    
    mask = mask_generator_2.generate(image_rgb)
    
    # Supongamos que tienes la lista 'masks2' como se menciona en la pregunta
    
    # Nombre del archivo .h5
    nombre_archivo = file_name[:-4] +'.h5'

    # Crear el archivo HDF5 en la carpeta de destino
    ruta_archivo_h5 = os.path.join(name, nombre_archivo)

    with h5py.File(ruta_archivo_h5, 'w') as hf:
        for idx, obj in enumerate(mask):
        # Obtener la matriz de segmentación de la máscara
            segmentation = obj['segmentation']

            # Crear una imagen en color del mismo tamaño que la matriz de segmentación
            imagen_segmentada = np.zeros(segmentation.shape + (3,), dtype=np.uint8)

            # Obtener los colores correspondientes de la imagen original
            colores_originales = image_rgb[segmentation]

            # Establecer los píxeles correspondientes a la segmentación con los colores originales
            imagen_segmentada[segmentation] = colores_originales

            # Guardar la imagen segmentada en la carpeta correspondiente
            nombre_imagen_segmentada = f"segmentacion_{idx + 1}.jpg"
            cv2.imwrite(os.path.join(nombre_carpeta_imagen, nombre_imagen_segmentada), cv2.cvtColor(imagen_segmentada, cv2.COLOR_RGB2BGR))

            
            #ARCHIVO
            group = hf.create_group(nombre_imagen_segmentada[:-4])
            group.create_dataset('segmentation', data=bool_array_to_uint8(obj['segmentation']))
            group.create_dataset('area', data=obj['area'])
            group.create_dataset('bbox', data=obj['bbox'])
            group.create_dataset('predicted_iou', data=obj['predicted_iou'])
            group.create_dataset('point_coords', data=obj['point_coords'])
            group.create_dataset('stability_score', data=obj['stability_score'])
            group.create_dataset('crop_box', data=obj['crop_box'])

# %%
# Función para convertir uint8 arrays a boolean arrays
def uint8_array_to_bool(array):
    return array.astype(bool)

# Leer el archivo HDF5
with h5py.File('1.h5', 'r') as hf:
    # Obtener las claves (nombres de los grupos) dentro del archivo HDF5
    group_keys = list(hf.keys())

    # Acceder a los datos de cada grupo dentro del archivo
    for key in group_keys:
        group = hf[key]
        segmentation = uint8_array_to_bool(group['segmentation'][:])
        area = group['area'][()]
        bbox = group['bbox'][:]
        predicted_iou = group['predicted_iou'][()]
        point_coords = group['point_coords'][:]
        stability_score = group['stability_score'][()]
        crop_box = group['crop_box'][:]

        # Ahora puedes trabajar con los datos obtenidos de cada grupo
        print(f"Datos del grupo {key}:")
        print("Segmentation:")
        print(segmentation)
        print("Area:", area)
        print("Bbox:", bbox)
        print("Predicted IoU:", predicted_iou)
        print("Point Coords:", point_coords)
        print("Stability Score:", stability_score)
        print("Crop Box:", crop_box)
        print("\n")
# Out:
# Datos del grupo segmentacion_1:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 14928
# Bbox: [ 771 1480  127  119]
# Predicted IoU: 1.0005661249160767
# Point Coords: [[ 873.375 1568.625]]
# Stability Score: 0.9907345771789551
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_10:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 8623
# Bbox: [670 997 134 102]
# Predicted IoU: 0.9790168404579163
# Point Coords: [[ 722.625 1066.625]]
# Stability Score: 0.9789087772369385
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_100:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 974
# Bbox: [593 354  33  44]
# Predicted IoU: 0.9537923336029053
# Point Coords: [[618.75 375.  ]]
# Stability Score: 0.9766497611999512
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_101:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 3382
# Bbox: [402 479  64  92]
# Predicted IoU: 0.9477941989898682
# Point Coords: [[431.25 525.  ]]
# Stability Score: 0.9774985313415527
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_102:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 733
# Bbox: [674 407  24  40]
# Predicted IoU: 0.9397270083427429
# Point Coords: [[693.75 425.  ]]
# Stability Score: 0.9756097793579102
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_103:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 11419
# Bbox: [  0 991  41 303]
# Predicted IoU: 0.9371585249900818
# Point Coords: [[  18.75 1125.  ]]
# Stability Score: 0.9395205974578857
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_104:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 447
# Bbox: [898 920  28  19]
# Predicted IoU: 0.9312025904655457
# Point Coords: [[918.75 925.  ]]
# Stability Score: 0.9822616577148438
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_105:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 9291
# Bbox: [ 949 1027  102  209]
# Predicted IoU: 0.9304329752922058
# Point Coords: [[1031.25 1125.  ]]
# Stability Score: 0.9653173089027405
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_106:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1570
# Bbox: [551 277  55  52]
# Predicted IoU: 0.9216502904891968
# Point Coords: [[581.25 325.  ]]
# Stability Score: 0.9655604362487793
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_107:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1603
# Bbox: [1010 1456   87   24]
# Predicted IoU: 0.9193625450134277
# Point Coords: [[1068.75 1475.  ]]
# Stability Score: 0.9649446606636047
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_108:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 4804
# Bbox: [ 525 1262  266   99]
# Predicted IoU: 0.9172816872596741
# Point Coords: [[ 656.25 1325.  ]]
# Stability Score: 0.9591919779777527
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_109:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1714
# Bbox: [781 966  42  59]
# Predicted IoU: 0.9070339798927307
# Point Coords: [[806.25 975.  ]]
# Stability Score: 0.9638761281967163
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_11:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1776
# Bbox: [735 901  42  60]
# Predicted IoU: 0.9770247340202332
# Point Coords: [[772.875 941.125]]
# Stability Score: 0.9821528196334839
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_110:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1560
# Bbox: [610 929  40  58]
# Predicted IoU: 0.9028257727622986
# Point Coords: [[618.75 975.  ]]
# Stability Score: 0.9415422677993774
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_111:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1175
# Bbox: [565 555  39  45]
# Predicted IoU: 0.9009518623352051
# Point Coords: [[581.25 575.  ]]
# Stability Score: 0.9714285731315613
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_112:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 469
# Bbox: [791 848  21  27]
# Predicted IoU: 0.8923322558403015
# Point Coords: [[806.25 875.  ]]
# Stability Score: 0.9768421053886414
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_113:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 953
# Bbox: [681 878  35  39]
# Predicted IoU: 0.8910922408103943
# Point Coords: [[693.75 875.  ]]
# Stability Score: 0.949999988079071
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_114:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 492
# Bbox: [826 976  24  32]
# Predicted IoU: 0.8875725865364075
# Point Coords: [[843.75 975.  ]]
# Stability Score: 0.9738956093788147
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_115:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 4805
# Bbox: [409 573 191  81]
# Predicted IoU: 0.8636957406997681
# Point Coords: [[543.75 625.  ]]
# Stability Score: 0.9552663564682007
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_116:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 62759
# Bbox: [536 803 400 232]
# Predicted IoU: 1.0324043035507202
# Point Coords: [[873.375 941.125]]
# Stability Score: 0.9558172821998596
# Crop Box: [ 396  596  804 1004]
# Datos del grupo segmentacion_117:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 158174
# Bbox: [439 730 588 598]
# Predicted IoU: 0.9978060126304626
# Point Coords: [[ 772.875 1254.875]]
# Stability Score: 0.9719851016998291
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_118:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 10330
# Bbox: [ 585 1088  148  121]
# Predicted IoU: 0.9231060743331909
# Point Coords: [[ 672.375 1192.125]]
# Stability Score: 0.9371277093887329
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_119:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 15125
# Bbox: [ 771 1480  210  119]
# Predicted IoU: 0.9129201769828796
# Point Coords: [[ 772.875 1505.875]]
# Stability Score: 0.9240702986717224
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_12:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2962
# Bbox: [ 834 1256   93   63]
# Predicted IoU: 0.975368082523346
# Point Coords: [[ 873.375 1317.625]]
# Stability Score: 0.9832720160484314
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_120:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2379
# Bbox: [781 950  49  74]
# Predicted IoU: 0.892471432685852
# Point Coords: [[ 823.125 1003.875]]
# Stability Score: 0.9442182183265686
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_121:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 23728
# Bbox: [ 555 1001  178  207]
# Predicted IoU: 0.8895537853240967
# Point Coords: [[ 672.375 1066.625]]
# Stability Score: 0.948127031326294
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_122:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 972
# Bbox: [549 910  35  39]
# Predicted IoU: 0.8610522150993347
# Point Coords: [[571.875 941.125]]
# Stability Score: 0.9355509281158447
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_123:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1849
# Bbox: [532 547  40  65]
# Predicted IoU: 0.9715479016304016
# Point Coords: [[571.875   596.71875]]
# Stability Score: 0.9749733805656433
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_124:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2287
# Bbox: [617 376  51  63]
# Predicted IoU: 0.9666322469711304
# Point Coords: [[622.125   408.28125]]
# Stability Score: 0.9713307619094849
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_125:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2339
# Bbox: [476 572  62  51]
# Predicted IoU: 0.9113953709602356
# Point Coords: [[521.625   596.71875]]
# Stability Score: 0.9462453722953796
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_126:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2908
# Bbox: [612 289  65  76]
# Predicted IoU: 0.8899868726730347
# Point Coords: [[672.375   345.46875]]
# Stability Score: 0.9507978558540344
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_127:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  [ True  True  True ... False False False]]
# Area: 10222
# Bbox: [   0 1300   36  299]
# Predicted IoU: 0.982433021068573
# Point Coords: [[  25.15625 1505.875  ]]
# Stability Score: 0.9753038287162781
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_128:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 4905
# Bbox: [ 308 1482   42  117]
# Predicted IoU: 0.9738313555717468
# Point Coords: [[ 327.03125 1568.625  ]]
# Stability Score: 0.9769557118415833
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_129:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 17911
# Bbox: [ 223 1480  427  119]
# Predicted IoU: 0.925748348236084
# Point Coords: [[ 276.71875 1568.625  ]]
# Stability Score: 0.9505780339241028
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_13:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1523
# Bbox: [600 850  44  50]
# Predicted IoU: 0.9741562604904175
# Point Coords: [[622.125 878.375]]
# Stability Score: 0.9837239384651184
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_130:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 43527
# Bbox: [ 309 1482  461  117]
# Predicted IoU: 0.9209394454956055
# Point Coords: [[ 528.28125 1568.625  ]]
# Stability Score: 0.9250039458274841
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_131:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 109251
# Bbox: [339 210 383 507]
# Predicted IoU: 1.0233145952224731
# Point Coords: [[578.59375 471.09375]]
# Stability Score: 0.9488810300827026
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_132:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 4053
# Bbox: [375 336  64  89]
# Predicted IoU: 0.9770733118057251
# Point Coords: [[427.65625 345.46875]]
# Stability Score: 0.9763760566711426
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_133:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1728
# Bbox: [613 501  76  34]
# Predicted IoU: 0.9414131045341492
# Point Coords: [[628.90625 533.90625]]
# Stability Score: 0.9225313663482666
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_134:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 857
# Bbox: [454 403  40  35]
# Predicted IoU: 0.9224377870559692
# Point Coords: [[477.96875 408.28125]]
# Stability Score: 0.9365591406822205
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_135:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 3472
# Bbox: [608 376  59  97]
# Predicted IoU: 0.8961200714111328
# Point Coords: [[628.90625 471.09375]]
# Stability Score: 0.9259877800941467
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_136:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 425802
# Bbox: [ 115   88  985 1393]
# Predicted IoU: 1.0093713998794556
# Point Coords: [[ 168.75 1375.  ]]
# Stability Score: 0.9789654016494751
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_137:
# Segmentation:
# [[False False False ...  True  True  True]
#  [False False False ...  True  True  True]
#  [False False False ...  True  True  True]
#  ...
#  [False False False ...  True  True  True]
#  [False False False ...  True  True  True]
#  [False False False ...  True  True  True]]
# Area: 144862
# Bbox: [1099    0  100 1599]
# Predicted IoU: 1.002602458000183
# Point Coords: [[1143.75   25.  ]]
# Stability Score: 0.9853423833847046
# Crop Box: [   0    0 1200 1600]
# Datos del grupo segmentacion_138:
# Segmentation:
# [[ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 277748
# Bbox: [   0    0  766 1599]
# Predicted IoU: 0.9947869777679443
# Point Coords: [[ 206.25 1575.  ]]
# Stability Score: 0.9645478129386902
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_139:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 364647
# Bbox: [ 173  264  876 1033]
# Predicted IoU: 0.9913558959960938
# Point Coords: [[618.75 725.  ]]
# Stability Score: 0.9777107238769531
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_14:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2908
# Bbox: [505 632  49  90]
# Predicted IoU: 0.9730718731880188
# Point Coords: [[521.625 690.125]]
# Stability Score: 0.9832878708839417
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_140:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 33113
# Bbox: [  0  60  59 610]
# Predicted IoU: 0.9487841725349426
# Point Coords: [[ 18.75 525.  ]]
# Stability Score: 0.9350572228431702
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_141:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 116376
# Bbox: [529 803 408 408]
# Predicted IoU: 0.9437752962112427
# Point Coords: [[693.75 975.  ]]
# Stability Score: 0.9437896013259888
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_142:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 19153
# Bbox: [214   0 407  66]
# Predicted IoU: 0.9354127049446106
# Point Coords: [[393.75  25.  ]]
# Stability Score: 0.9318976402282715
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_143:
# Segmentation:
# [[False False False ...  True  True  True]
#  [False False False ...  True  True  True]
#  [False False False ...  True  True  True]
#  ...
#  [False False False ...  True False False]
#  [False False False ...  True False False]
#  [False False False ...  True False False]]
# Area: 185986
# Bbox: [1002    0  197 1599]
# Predicted IoU: 0.9352538585662842
# Point Coords: [[1106.25  725.  ]]
# Stability Score: 0.9216864705085754
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_144:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 9579
# Bbox: [ 844 1026  207  290]
# Predicted IoU: 0.9290885329246521
# Point Coords: [[1031.25 1075.  ]]
# Stability Score: 0.942952036857605
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_145:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2378
# Bbox: [834 889  62  50]
# Predicted IoU: 0.9111195802688599
# Point Coords: [[881.25 925.  ]]
# Stability Score: 0.9283139705657959
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_146:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 44199
# Bbox: [   6 1482  765  117]
# Predicted IoU: 0.8999418020248413
# Point Coords: [[ 693.75 1525.  ]]
# Stability Score: 0.9304556250572205
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_147:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 3721
# Bbox: [833   0 179  33]
# Predicted IoU: 0.8937622904777527
# Point Coords: [[956.25  25.  ]]
# Stability Score: 0.9235880374908447
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_148:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1471
# Bbox: [688 493  37  66]
# Predicted IoU: 0.8914385437965393
# Point Coords: [[693.75 525.  ]]
# Stability Score: 0.9492419362068176
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_149:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 171481
# Bbox: [ 115 1089  952  390]
# Predicted IoU: 0.8843292593955994
# Point Coords: [[ 506.25 1325.  ]]
# Stability Score: 0.9236007332801819
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_15:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 577
# Bbox: [713 807  30  25]
# Predicted IoU: 0.9721794724464417
# Point Coords: [[722.625 815.625]]
# Stability Score: 0.9794167876243591
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_150:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 4324
# Bbox: [375 572  98 113]
# Predicted IoU: 0.8758895397186279
# Point Coords: [[393.75 675.  ]]
# Stability Score: 0.9210174083709717
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_16:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 8308
# Bbox: [ 911 1479   70  120]
# Predicted IoU: 0.9680269956588745
# Point Coords: [[ 923.625 1568.625]]
# Stability Score: 0.9727866649627686
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_17:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 7921
# Bbox: [ 578 1480   68  119]
# Predicted IoU: 0.9640730023384094
# Point Coords: [[ 622.125 1568.625]]
# Stability Score: 0.9648709297180176
# Crop Box: [ 396  596  804 1004]
# Datos del grupo segmentacion_18:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1079
# Bbox: [822 804  36  42]
# Predicted IoU: 0.9572524428367615
# Point Coords: [[823.125 815.625]]
# Stability Score: 0.9779816269874573
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_19:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1433
# Bbox: [655 901  42  48]
# Predicted IoU: 0.9563202857971191
# Point Coords: [[672.375 941.125]]
# Stability Score: 0.9765193462371826
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_2:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1277
# Bbox: [691 933  44  37]
# Predicted IoU: 0.9902549386024475
# Point Coords: [[722.625 941.125]]
# Stability Score: 0.9906542301177979
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_20:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1101
# Bbox: [551 837  29  58]
# Predicted IoU: 0.9538604021072388
# Point Coords: [[571.875 878.375]]
# Stability Score: 0.9741532802581787
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_21:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2280
# Bbox: [ 962 1479   19  120]
# Predicted IoU: 0.9514028429985046
# Point Coords: [[ 973.875 1568.625]]
# Stability Score: 0.9674796462059021
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_22:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 995
# Bbox: [821 936  37  37]
# Predicted IoU: 0.9501132369041443
# Point Coords: [[823.125 941.125]]
# Stability Score: 0.9781312346458435
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_23:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 590
# Bbox: [908 878  28  32]
# Predicted IoU: 0.9490246772766113
# Point Coords: [[923.625 878.375]]
# Stability Score: 0.9750000238418579
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_24:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1137
# Bbox: [736 811  55  41]
# Predicted IoU: 0.9478106498718262
# Point Coords: [[772.875 815.625]]
# Stability Score: 0.9620689749717712
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_25:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1137
# Bbox: [611 929  40  38]
# Predicted IoU: 0.94035404920578
# Point Coords: [[622.125 941.125]]
# Stability Score: 0.9756521582603455
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_26:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 601
# Bbox: [551 865  27  30]
# Predicted IoU: 0.939301073551178
# Point Coords: [[571.875 878.375]]
# Stability Score: 0.9706361889839172
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_27:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1513
# Bbox: [637 805  39  46]
# Predicted IoU: 0.9350347518920898
# Point Coords: [[672.375 815.625]]
# Stability Score: 0.9638476371765137
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_28:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 650
# Bbox: [770 877  25  33]
# Predicted IoU: 0.9338751435279846
# Point Coords: [[772.875 878.375]]
# Stability Score: 0.978723406791687
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_29:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 877
# Bbox: [650 870  42  28]
# Predicted IoU: 0.9336815476417542
# Point Coords: [[672.375 878.375]]
# Stability Score: 0.9728199243545532
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_3:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 10562
# Bbox: [ 732 1067  117  122]
# Predicted IoU: 0.9860339760780334
# Point Coords: [[ 772.875 1129.375]]
# Stability Score: 0.9566428661346436
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_30:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1700
# Bbox: [549 887  41  63]
# Predicted IoU: 0.9332675933837891
# Point Coords: [[571.875 941.125]]
# Stability Score: 0.9670710563659668
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_31:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 47915
# Bbox: [554 997 303 212]
# Predicted IoU: 0.9316685199737549
# Point Coords: [[ 722.625 1066.625]]
# Stability Score: 0.9625452756881714
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_32:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 21217
# Bbox: [562 997 242 135]
# Predicted IoU: 0.9255539178848267
# Point Coords: [[ 722.625 1066.625]]
# Stability Score: 0.9603837132453918
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_33:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 224
# Bbox: [616 683  20  15]
# Predicted IoU: 0.9208057522773743
# Point Coords: [[622.125 690.125]]
# Stability Score: 0.9605262875556946
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_34:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1104
# Bbox: [713 876  34  40]
# Predicted IoU: 0.9145264029502869
# Point Coords: [[722.625 878.375]]
# Stability Score: 0.951241135597229
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_35:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1305
# Bbox: [543 986  48  51]
# Predicted IoU: 0.8942561745643616
# Point Coords: [[ 571.875 1003.875]]
# Stability Score: 0.9565542936325073
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_36:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 489
# Bbox: [796 874  26  24]
# Predicted IoU: 0.8865752816200256
# Point Coords: [[823.125 878.375]]
# Stability Score: 0.9637096524238586
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_37:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1789
# Bbox: [822 804  39  60]
# Predicted IoU: 0.8779298067092896
# Point Coords: [[823.125 815.625]]
# Stability Score: 0.9756906032562256
# Crop Box: [ 396  596  804 1004]
# Datos del grupo segmentacion_38:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 3289
# Bbox: [453 203  72  92]
# Predicted IoU: 0.9802801012992859
# Point Coords: [[521.625   282.65625]]
# Stability Score: 0.9806879758834839
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_39:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 5093
# Bbox: [455 204  85 122]
# Predicted IoU: 0.9775390625
# Point Coords: [[521.625   282.65625]]
# Stability Score: 0.9763014912605286
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_4:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 772
# Bbox: [714 984  27  36]
# Predicted IoU: 0.9842739105224609
# Point Coords: [[ 722.625 1003.875]]
# Stability Score: 0.9819819927215576
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_40:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1053
# Bbox: [592  19  38  33]
# Predicted IoU: 0.9746227860450745
# Point Coords: [[622.125    31.40625]]
# Stability Score: 0.9877126812934875
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_41:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1517
# Bbox: [645 561  32  58]
# Predicted IoU: 0.9715807437896729
# Point Coords: [[672.375   596.71875]]
# Stability Score: 0.9791259169578552
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_42:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 5972
# Bbox: [784   0 269  50]
# Predicted IoU: 0.9668360948562622
# Point Coords: [[873.375    31.40625]]
# Stability Score: 0.9735842943191528
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_43:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1067
# Bbox: [562 521  41  34]
# Predicted IoU: 0.9661121368408203
# Point Coords: [[571.875   533.90625]]
# Stability Score: 0.9823583960533142
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_44:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 942
# Bbox: [800 900  35  39]
# Predicted IoU: 0.96463543176651
# Point Coords: [[823.125   910.78125]]
# Stability Score: 0.9862724542617798
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_45:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2231
# Bbox: [637 452  66  48]
# Predicted IoU: 0.9630054831504822
# Point Coords: [[672.375   471.09375]]
# Stability Score: 0.9716939330101013
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_46:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1467
# Bbox: [851 893  45  43]
# Predicted IoU: 0.9594098329544067
# Point Coords: [[873.375   910.78125]]
# Stability Score: 0.9757412672042847
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_47:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 439
# Bbox: [558 836  17  33]
# Predicted IoU: 0.956866979598999
# Point Coords: [[571.875   847.96875]]
# Stability Score: 0.9775280952453613
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_48:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 773
# Bbox: [855 951  32  31]
# Predicted IoU: 0.9552940726280212
# Point Coords: [[873.375   973.59375]]
# Stability Score: 0.9820051193237305
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_49:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 652
# Bbox: [706 830  22  44]
# Predicted IoU: 0.9541980624198914
# Point Coords: [[722.625   847.96875]]
# Stability Score: 0.9653614163398743
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_5:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 13802
# Bbox: [ 655 1481  116  118]
# Predicted IoU: 0.9836685061454773
# Point Coords: [[ 672.375 1505.875]]
# Stability Score: 0.9890497922897339
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_50:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1313
# Bbox: [607 424  36  50]
# Predicted IoU: 0.9511813521385193
# Point Coords: [[622.125   471.09375]]
# Stability Score: 0.9752438068389893
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_51:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1189
# Bbox: [632 325  45  40]
# Predicted IoU: 0.9509884119033813
# Point Coords: [[672.375   345.46875]]
# Stability Score: 0.9799330830574036
# Crop Box: [ 396    0  804 1005]
#
#
# Datos del grupo segmentacion_52:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 3252
# ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 5773
# Bbox: [ 912 1479   49  120]
# Predicted IoU: 0.9817101955413818
# Point Coords: [[ 923.625 1568.625]]
# Stability Score: 0.9696038365364075
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_70:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 10297
# Bbox: [ 227 1188  314  101]
# Predicted IoU: 0.9686480164527893
# Point Coords: [[ 477.96875 1254.875  ]]
# Stability Score: 0.969204306602478
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_71:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 25606
# Bbox: [ 310 1483  258  116]
# Predicted IoU: 0.9560038447380066
# Point Coords: [[ 477.96875 1505.875  ]]
# Stability Score: 0.9207767248153687
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_72:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 271
# Bbox: [ 627 1238   15   20]
# Predicted IoU: 0.9539667367935181
# Point Coords: [[ 628.90625 1254.875  ]]
# Stability Score: 0.9818181991577148
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_73:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1715
# Bbox: [678 961  62  59]
# Predicted IoU: 0.9152505397796631
# Point Coords: [[ 729.53125 1003.875  ]]
# Stability Score: 0.9598624110221863
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_74:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 479
# Bbox: [579 908  19  34]
# Predicted IoU: 0.8982016444206238
# Point Coords: [[578.59375 941.125  ]]
# Stability Score: 0.969072163105011
# Crop Box: [   0  596  805 1004]
#
#
# Datos del grupo segmentacion_75:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 594
# Bbox: [527 884  23  34]
# Predicted IoU: 0.9793975949287415
# Point Coords: [[528.28125 910.78125]]
# Stability Score: 0.9932885766029358
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_76:
# Segmentation:
# [[ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  [ True  True  True ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 3346
# Bbox: [ 0  0 60 56]
# Predicted IoU: 0.9781209230422974
# Point Coords: [[25.15625 31.40625]]
# Stability Score: 0.9863864779472351
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_77:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1767
# Bbox: [430 421  48  60]
# Predicted IoU: 0.9618627429008484
# Point Coords: [[477.96875 471.09375]]
# Stability Score: 0.9722067713737488
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_78:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1049
# Bbox: [358 472  35  43]
# Predicted IoU: 0.9560176730155945
# Point Coords: [[377.34375 471.09375]]
# Stability Score: 0.969924807548523
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_79:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 698
# Bbox: [722 839  27  34]
# Predicted IoU: 0.9531188011169434
# Point Coords: [[729.53125 847.96875]]
# Stability Score: 0.9716714024543762
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_8:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 11284
# Bbox: [1002 1475   92  124]
# Predicted IoU: 0.9815189242362976
# Point Coords: [[1024.125 1505.875]]
# Stability Score: 0.9831149578094482
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_80:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 40532
# Bbox: [ 62   0 179 363]
# Predicted IoU: 0.9517893195152283
# Point Coords: [[ 75.46875 282.65625]]
# Stability Score: 0.9791641235351562
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_81:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1443
# Bbox: [408 342  32  70]
# Predicted IoU: 0.9494504332542419
# Point Coords: [[427.65625 345.46875]]
# Stability Score: 0.9646499156951904
# Crop Box: [   0    0  805 1005]
# Datos del grupo segmentacion_82:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1991
# Bbox: [565 553  43  68]
# Predicted IoU: 0.9472264051437378
# Point Coords: [[578.59375 596.71875]]
# Stability Score: 0.9722359776496887
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_83:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 749
# Bbox: [676 902  21  44]
# Predicted IoU: 0.9327921271324158
# Point Coords: [[679.21875 910.78125]]
# Stability Score: 0.9581699371337891
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_84:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2325
# Bbox: [374 612  70  74]
# Predicted IoU: 0.9326649904251099
# Point Coords: [[377.34375 659.53125]]
# Stability Score: 0.9749788045883179
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_85:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 844
# Bbox: [492 401  50  29]
# Predicted IoU: 0.9287168383598328
# Point Coords: [[528.28125 408.28125]]
# Stability Score: 0.9699074029922485
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_86:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1245
# Bbox: [415 379  44  57]
# Predicted IoU: 0.924306333065033
# Point Coords: [[427.65625 408.28125]]
# Stability Score: 0.9746031761169434
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_87:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 849
# Bbox: [548 323  42  26]
# Predicted IoU: 0.9132214188575745
# Point Coords: [[578.59375 345.46875]]
# Stability Score: 0.9563218355178833
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_88:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1699
# Bbox: [577 818  44  50]
# Predicted IoU: 0.9094607830047607
# Point Coords: [[578.59375 847.96875]]
# Stability Score: 0.971528172492981
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_89:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 766
# Bbox: [374 655  36  31]
# Predicted IoU: 0.8906732201576233
# Point Coords: [[377.34375 659.53125]]
# Stability Score: 0.9354430437088013
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_9:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 11937
# Bbox: [ 567 1001  128  130]
# Predicted IoU: 0.9813897013664246
# Point Coords: [[ 622.125 1066.625]]
# Stability Score: 0.9753291010856628
# Crop Box: [ 396  596  804 1004]
#
#
# Datos del grupo segmentacion_90:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1081
# Bbox: [559 377  44  35]
# Predicted IoU: 0.8766412138938904
# Point Coords: [[578.59375 408.28125]]
# Stability Score: 0.9401251077651978
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_91:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1569
# Bbox: [342 467  51  49]
# Predicted IoU: 0.8676655292510986
# Point Coords: [[377.34375 471.09375]]
# Stability Score: 0.945027768611908
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_92:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 53375
# Bbox: [ 48 368 106 613]
# Predicted IoU: 0.865990936756134
# Point Coords: [[ 75.46875 659.53125]]
# Stability Score: 0.92538982629776
# Crop Box: [   0    0  805 1005]
#
#
# Datos del grupo segmentacion_93:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 90166
# Bbox: [182   0 927 146]
# Predicted IoU: 1.0099469423294067
# Point Coords: [[356.25  25.  ]]
# Stability Score: 0.9838812351226807
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_94:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 15016
# Bbox: [ 227 1188  562  172]
# Predicted IoU: 0.9822252988815308
# Point Coords: [[ 506.25 1275.  ]]
# Stability Score: 0.9682789444923401
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_95:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2114
# Bbox: [519 465  53  61]
# Predicted IoU: 0.9812099933624268
# Point Coords: [[543.75 475.  ]]
# Stability Score: 0.9807962775230408
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_96:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1734
# Bbox: [611 288  50  53]
# Predicted IoU: 0.9759249687194824
# Point Coords: [[618.75 325.  ]]
# Stability Score: 0.9868345856666565
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_97:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2532
# Bbox: [525 608  75  46]
# Predicted IoU: 0.9680431485176086
# Point Coords: [[581.25 625.  ]]
# Stability Score: 0.9739299416542053
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_98:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 1151
# Bbox: [569 276  36  53]
# Predicted IoU: 0.96168452501297
# Point Coords: [[581.25 325.  ]]
# Stability Score: 0.9776440262794495
# Crop Box: [   0    0 1200 1600]
#
#
# Datos del grupo segmentacion_99:
# Segmentation:
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# Area: 2556
# Bbox: [ 981 1477   22  122]
# Predicted IoU: 0.9610532522201538
# Point Coords: [[ 993.75 1575.  ]]
# Stability Score: 0.9691833853721619
# Crop Box: [   0    0 1200 1600]
